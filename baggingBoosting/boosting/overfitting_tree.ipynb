# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.rand(100, 3), columns=['A', 'B', 'C'])
df.head()
# Out:
#           A         B         C
# 0  0.935143  0.637620  0.603147
# 1  0.092416  0.193968  0.725660
# 2  0.060061  0.156640  0.775164
# 3  0.612889  0.008836  0.910081
# 4  0.379455  0.035896  0.158769

# %%
df.drop(columns=['A'], inplace=True)

# %%
df.shape
# Out:
# (100, 2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['B'], df['C'], alpha=0.5)
plt.show()

# %%
X = df['B']
y = df['C']

from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor(max_depth=100, random_state=42)
dt_model.fit(X.values.reshape(-1, 1), y)
# Out:
# DecisionTreeRegressor(max_depth=100, random_state=42)

# %%
y_pred = dt_model.predict(X.values.reshape(-1, 1))

# %%
# plotting the prediction line
plt.figure(figsize=(10,6))
plt.scatter(df['B'], df['C'], alpha=0.5)
plt.plot(df['B'], y_pred, color='red')
plt.show()
